# %%
import numpy as np
import pandas as pd

# %%
data=pd.read_csv("Wine_Quality1.csv")

# %%
data
# Out:
#    Fixed Acidity  Volatile Acidity  Citric Acid  Residual Sugar  Chlorides  \
# 0            7.3              0.80         0.00             1.8      0.076
# 1            7.4              0.90         0.00             2.9      0.098
# 2            7.9              0.78         0.06             2.4      0.092
# 3           11.2              0.34         0.54             1.8      0.075
# 4            7.8              0.74         0.35             2.2      0.078
# 5            7.2              0.76         0.00             2.6      0.090
# 6            7.9              0.98         0.48             3.2      0.098
# 7            8.6              0.32         0.66             3.0      0.082
# 8            8.2              0.46         0.08             3.4      0.088
# 9           11.4              0.86         0.00             2.8      0.098
#
#    Free Sulfur dioxide  Total Sulfur dioxide  Density    pH  Sulphates  \
# 0                   12                    34   0.9978  3.51       0.56
# 1                   26                    67   0.9968  3.20       0.68
# 2                   16                    54   0.9970  3.26       0.65
# 3                   19                    60   0.9980  3.16       0.58
# 4                   15                    36   0.9998  3.71       0.70
# 5                   27                    63   0.9990  3.40       0.63
# 6                   18                    59   0.8670  3.60       0.66
# 7                   23                    68   0.7650  3.23       0.76
# 8                   19                    38   0.9970  3.50       0.55
# 9                   27                    67   0.9968  3.20       0.68
#
#    Alcohol  Quality
# 0      9.7        5
# 1      9.8        6
# 2      9.8        5
# 3      9.7        5
# 4      9.4        6
# 5      9.2        5
# 6      9.0        6
# 7      9.6        6
# 8      9.8        6
# 9      9.9        5

# %%
data.head()
# Out:
#    Fixed Acidity  Volatile Acidity  Citric Acid  Residual Sugar  Chlorides  \
# 0            7.3              0.80         0.00             1.8      0.076
# 1            7.4              0.90         0.00             2.9      0.098
# 2            7.9              0.78         0.06             2.4      0.092
# 3           11.2              0.34         0.54             1.8      0.075
# 4            7.8              0.74         0.35             2.2      0.078
#
#    Free Sulfur dioxide  Total Sulfur dioxide  Density    pH  Sulphates  \
# 0                   12                    34   0.9978  3.51       0.56
# 1                   26                    67   0.9968  3.20       0.68
# 2                   16                    54   0.9970  3.26       0.65
# 3                   19                    60   0.9980  3.16       0.58
# 4                   15                    36   0.9998  3.71       0.70
#
#    Alcohol  Quality
# 0      9.7        5
# 1      9.8        6
# 2      9.8        5
# 3      9.7        5
# 4      9.4        6

# %%
X=data.drop('Quality', axis=1)
y=data['Quality']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test=train_test_split(X,y,test_size=0.8,random_state=48)

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=model.predict(X_test)

# %%
from sklearn.metrics import mean_squared_error,r2_score
mse = mean_squared_error(y_test,y_pred)
r2=r2_score(y_test,y_pred)
print(f'Mean Squared Error:{mse}')
print(f'R-squared:{r2}')
# Out:
# Mean Squared Error:0.625
# R-squared:-1.6666666666666665

# %%
import matplotlib.pyplot as plt
plt.scatter(y_test, y_pred)
plt.xlabel("Actual Wine Quality")
plt.ylabel("Predicted Wine Quality")
plt.title("Actual Wine Quality vs. Predicted Wine Quality")
plt.show()
